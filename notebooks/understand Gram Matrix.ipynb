# %%
import os 
import torch 
import torch.nn as nn 
import torch.optim as optim 
import torchvision.models as models
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F 
import cv2

# %%
x = torch.rand((1, 64, 30, 30))
B, C, H, W = x.shape

# %%
fm_flat = x.view(C, H * W)
output = torch.mm(fm_flat, fm_flat.t())

# %%
print(output.shape)
# Out:
# torch.Size([64, 64])

# %%
# The output make sense, because the input is a random number and only things that's correlated is the central line 
plt.figure()
plt.imshow(out)
plt.colorbar()
plt.show()
